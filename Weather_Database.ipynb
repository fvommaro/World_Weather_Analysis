# %%
# Import the random module.
import random

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import WEATHER_API_KEY

# %%
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + WEATHER_API_KEY

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country" : city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | lieksa
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | tromso
# Processing Record 6 of Set 1 | boa vista
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | dhidhdhoo
# Processing Record 9 of Set 1 | lata
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | pevek
# Processing Record 14 of Set 1 | verkhnyaya toyma
# Processing Record 15 of Set 1 | vila velha
# Processing Record 16 of Set 1 | cajati
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | mitoc
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | santa cruz de tenerife
# Processing Record 25 of Set 1 | micheweni
# Processing Record 26 of Set 1 | mehamn
# Processing Record 27 of Set 1 | lapeer
# Processing Record 28 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 1 | namibe
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | codrington
# Processing Record 36 of Set 1 | lompoc
# Processing Record 37 of Set 1 | klaksvik
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | boone
# Processing Record 40 of Set 1 | saldanha
# Processing Record 41 of Set 1 | porbandar
# Processing Record 42 of Set 1 | serang
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | batagay-alyta
# Processing Record 45 of Set 1 | melbu
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | nemuro
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | talnakh
# Processing Record 2 of Set 2 | batuan
# Processing Record 3 of Set 2 | te anau
# Processing Record 4 of Set 2 | marsh harbour
# Processing Record 5 of Set 2 | acapulco
# Processing Record 6 of Set 2 | gazanjyk
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | najran
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | jertih
# Processing Record 11 of Set 2 | kahului
# Processing Record 12 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | viedma
# Processing Record 15 of Set 2 | zelenoborsk
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | khani
# Processing Record 19 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 2 | mahebourg
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | ponta do sol
# Processing Record 23 of Set 2 | camana
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | tasiilaq
# Processing Record 26 of Set 2 | berlevag
# Processing Record 27 of Set 2 | sao sepe
# Processing Record 28 of Set 2 | mitsamiouli
# Processing Record 29 of Set 2 | tsentralnyy
# City not found. Skipping...
# Processing Record 30 of Set 2 | san luis
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | katsuura
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | comodoro rivadavia
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | buala
# Processing Record 37 of Set 2 | pozo colorado
# Processing Record 38 of Set 2 | havelock
# Processing Record 39 of Set 2 | norman wells
# Processing Record 40 of Set 2 | pemangkat
# Processing Record 41 of Set 2 | beckley
# Processing Record 42 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 2 | esperance
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | riyadh
# Processing Record 46 of Set 2 | saint george
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | arlit
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | margate
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | dudinka
# Processing Record 4 of Set 3 | beringovskiy
# Processing Record 5 of Set 3 | mahajanga
# Processing Record 6 of Set 3 | sarrebourg
# Processing Record 7 of Set 3 | northam
# Processing Record 8 of Set 3 | villaviciosa
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | lipin bor
# Processing Record 11 of Set 3 | awbari
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | usinsk
# Processing Record 14 of Set 3 | henties bay
# Processing Record 15 of Set 3 | san patricio
# Processing Record 16 of Set 3 | mwinilunga
# Processing Record 17 of Set 3 | baruun-urt
# Processing Record 18 of Set 3 | lebu
# Processing Record 19 of Set 3 | hilo
# Processing Record 20 of Set 3 | gravdal
# Processing Record 21 of Set 3 | sarkand
# Processing Record 22 of Set 3 | atuona
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | coihaique
# Processing Record 25 of Set 3 | borogontsy
# Processing Record 26 of Set 3 | port hardy
# Processing Record 27 of Set 3 | bilibino
# Processing Record 28 of Set 3 | fort nelson
# Processing Record 29 of Set 3 | kungurtug
# Processing Record 30 of Set 3 | bathsheba
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | asau
# Processing Record 33 of Set 3 | ler
# Processing Record 34 of Set 3 | mahibadhoo
# Processing Record 35 of Set 3 | benghazi
# Processing Record 36 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 3 | menomonie
# Processing Record 38 of Set 3 | rawson
# Processing Record 39 of Set 3 | wuhu
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | acurenam
# Processing Record 42 of Set 3 | kandrian
# Processing Record 43 of Set 3 | pascagoula
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | namatanai
# Processing Record 46 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 3 | paamiut
# Processing Record 48 of Set 3 | kurilsk
# Processing Record 49 of Set 3 | saint-georges
# Processing Record 50 of Set 3 | campo formoso
# Processing Record 1 of Set 4 | rodrigues alves
# Processing Record 2 of Set 4 | vestmannaeyjar
# Processing Record 3 of Set 4 | umm lajj
# Processing Record 4 of Set 4 | ribeira grande
# Processing Record 5 of Set 4 | baiyin
# Processing Record 6 of Set 4 | nicoya
# Processing Record 7 of Set 4 | mandalgovi
# Processing Record 8 of Set 4 | togul
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | thinadhoo
# Processing Record 11 of Set 4 | dulmen
# Processing Record 12 of Set 4 | flora
# Processing Record 13 of Set 4 | dingle
# Processing Record 14 of Set 4 | tilichiki
# Processing Record 15 of Set 4 | sena madureira
# Processing Record 16 of Set 4 | nishihara
# Processing Record 17 of Set 4 | sur
# Processing Record 18 of Set 4 | barrow
# Processing Record 19 of Set 4 | altay
# Processing Record 20 of Set 4 | victoria
# Processing Record 21 of Set 4 | evensk
# Processing Record 22 of Set 4 | dolores
# Processing Record 23 of Set 4 | srednekolymsk
# Processing Record 24 of Set 4 | kavieng
# Processing Record 25 of Set 4 | minas
# Processing Record 26 of Set 4 | chuy
# Processing Record 27 of Set 4 | port blair
# Processing Record 28 of Set 4 | erenhot
# Processing Record 29 of Set 4 | dubbo
# Processing Record 30 of Set 4 | khatanga
# Processing Record 31 of Set 4 | maldonado
# Processing Record 32 of Set 4 | kulhudhuffushi
# Processing Record 33 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 4 | byron bay
# Processing Record 35 of Set 4 | torata
# Processing Record 36 of Set 4 | kautokeino
# Processing Record 37 of Set 4 | jurm
# Processing Record 38 of Set 4 | chekhov
# Processing Record 39 of Set 4 | hamilton
# Processing Record 40 of Set 4 | fairbanks
# Processing Record 41 of Set 4 | bhilai
# Processing Record 42 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | zarya
# Processing Record 44 of Set 4 | airai
# Processing Record 45 of Set 4 | new norfolk
# Processing Record 46 of Set 4 | sao filipe
# Processing Record 47 of Set 4 | barabai
# Processing Record 48 of Set 4 | malanje
# Processing Record 49 of Set 4 | karratha
# Processing Record 50 of Set 4 | jutai
# Processing Record 1 of Set 5 | huarmey
# Processing Record 2 of Set 5 | vanimo
# Processing Record 3 of Set 5 | ketchikan
# Processing Record 4 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 5 | atar
# Processing Record 6 of Set 5 | tomatlan
# Processing Record 7 of Set 5 | porto novo
# Processing Record 8 of Set 5 | ayagoz
# Processing Record 9 of Set 5 | gao
# Processing Record 10 of Set 5 | high rock
# Processing Record 11 of Set 5 | shimoda
# Processing Record 12 of Set 5 | alta floresta
# Processing Record 13 of Set 5 | provideniya
# Processing Record 14 of Set 5 | kieta
# Processing Record 15 of Set 5 | labytnangi
# Processing Record 16 of Set 5 | ajdabiya
# Processing Record 17 of Set 5 | xining
# Processing Record 18 of Set 5 | butaritari
# Processing Record 19 of Set 5 | longyearbyen
# Processing Record 20 of Set 5 | umarga
# Processing Record 21 of Set 5 | kambove
# Processing Record 22 of Set 5 | frontera
# Processing Record 23 of Set 5 | meadow lake
# Processing Record 24 of Set 5 | la macarena
# Processing Record 25 of Set 5 | damietta
# Processing Record 26 of Set 5 | boende
# Processing Record 27 of Set 5 | nizwa
# Processing Record 28 of Set 5 | vradiyivka
# Processing Record 29 of Set 5 | ornskoldsvik
# Processing Record 30 of Set 5 | pandan
# Processing Record 31 of Set 5 | amalapuram
# Processing Record 32 of Set 5 | kargasok
# Processing Record 33 of Set 5 | wamba
# Processing Record 34 of Set 5 | naze
# Processing Record 35 of Set 5 | vila franca do campo
# Processing Record 36 of Set 5 | jalingo
# Processing Record 37 of Set 5 | kawalu
# Processing Record 38 of Set 5 | la ronge
# Processing Record 39 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 5 | montepuez
# Processing Record 41 of Set 5 | dali
# Processing Record 42 of Set 5 | meaford
# Processing Record 43 of Set 5 | sturgeon falls
# Processing Record 44 of Set 5 | santa marta
# Processing Record 45 of Set 5 | panama city
# Processing Record 46 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 5 | nuevo casas grandes
# Processing Record 48 of Set 5 | grindavik
# Processing Record 49 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 50 of Set 5 | ancud
# Processing Record 1 of Set 6 | seoul
# Processing Record 2 of Set 6 | clyde river
# Processing Record 3 of Set 6 | nara
# Processing Record 4 of Set 6 | mnogovershinnyy
# Processing Record 5 of Set 6 | half moon bay
# Processing Record 6 of Set 6 | igrim
# Processing Record 7 of Set 6 | esmeralda
# Processing Record 8 of Set 6 | hofn
# Processing Record 9 of Set 6 | danville
# Processing Record 10 of Set 6 | waipawa
# Processing Record 11 of Set 6 | dubrovnik
# Processing Record 12 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 6 | ipixuna
# Processing Record 14 of Set 6 | tuatapere
# Processing Record 15 of Set 6 | altamira
# Processing Record 16 of Set 6 | orai
# Processing Record 17 of Set 6 | huilong
# Processing Record 18 of Set 6 | lorengau
# Processing Record 19 of Set 6 | mersing
# Processing Record 20 of Set 6 | kismayo
# Processing Record 21 of Set 6 | ossora
# Processing Record 22 of Set 6 | tautira
# Processing Record 23 of Set 6 | nhulunbuy
# Processing Record 24 of Set 6 | ahmadpur east
# Processing Record 25 of Set 6 | burnie
# Processing Record 26 of Set 6 | cayenne
# Processing Record 27 of Set 6 | laval
# Processing Record 28 of Set 6 | kankon
# Processing Record 29 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 6 | yuzhno-kurilsk
# Processing Record 31 of Set 6 | conakry
# Processing Record 32 of Set 6 | mehran
# Processing Record 33 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 6 | puerto escondido
# Processing Record 35 of Set 6 | lavrentiya
# Processing Record 36 of Set 6 | juneau
# Processing Record 37 of Set 6 | dunnville
# Processing Record 38 of Set 6 | pozoblanco
# Processing Record 39 of Set 6 | taoudenni
# Processing Record 40 of Set 6 | bubaque
# Processing Record 41 of Set 6 | todos santos
# Processing Record 42 of Set 6 | pochutla
# Processing Record 43 of Set 6 | kavaratti
# Processing Record 44 of Set 6 | avera
# Processing Record 45 of Set 6 | adrar
# Processing Record 46 of Set 6 | san cristobal
# Processing Record 47 of Set 6 | santa rosa
# Processing Record 48 of Set 6 | dillon
# Processing Record 49 of Set 6 | sioux lookout
# Processing Record 50 of Set 6 | mattawa
# Processing Record 1 of Set 7 | haines junction
# Processing Record 2 of Set 7 | oistins
# Processing Record 3 of Set 7 | obo
# Processing Record 4 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 7 | dumabato
# Processing Record 6 of Set 7 | rafai
# Processing Record 7 of Set 7 | hirara
# Processing Record 8 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 7 | la libertad
# Processing Record 10 of Set 7 | fortuna
# Processing Record 11 of Set 7 | alekseyevsk
# Processing Record 12 of Set 7 | oktyabrskoye
# Processing Record 13 of Set 7 | port macquarie
# Processing Record 14 of Set 7 | lac du bonnet
# Processing Record 15 of Set 7 | carnarvon
# Processing Record 16 of Set 7 | dawei
# Processing Record 17 of Set 7 | bayshore gardens
# Processing Record 18 of Set 7 | kenai
# Processing Record 19 of Set 7 | luanda
# Processing Record 20 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 7 | xinzhou
# Processing Record 22 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 7 | denau
# City not found. Skipping...
# Processing Record 24 of Set 7 | morant bay
# Processing Record 25 of Set 7 | staryy nadym
# Processing Record 26 of Set 7 | nadym
# Processing Record 27 of Set 7 | coutances
# Processing Record 28 of Set 7 | hay river
# Processing Record 29 of Set 7 | voyvozh
# Processing Record 30 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 7 | warmbad
# Processing Record 32 of Set 7 | amga
# Processing Record 33 of Set 7 | neuquen
# Processing Record 34 of Set 7 | sao jose da coroa grande
# Processing Record 35 of Set 7 | non sang
# Processing Record 36 of Set 7 | rio grande
# Processing Record 37 of Set 7 | kiama
# Processing Record 38 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 7 | ahipara
# Processing Record 40 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 7 | bam
# Processing Record 42 of Set 7 | odessa
# Processing Record 43 of Set 7 | bethel
# Processing Record 44 of Set 7 | harper
# Processing Record 45 of Set 7 | isangel
# Processing Record 46 of Set 7 | itarema
# Processing Record 47 of Set 7 | mokhsogollokh
# Processing Record 48 of Set 7 | hammerfest
# Processing Record 49 of Set 7 | sola
# Processing Record 50 of Set 7 | ndele
# Processing Record 1 of Set 8 | santa maria
# Processing Record 2 of Set 8 | bonnyville
# Processing Record 3 of Set 8 | biltine
# Processing Record 4 of Set 8 | lerik
# Processing Record 5 of Set 8 | aklavik
# Processing Record 6 of Set 8 | cabo san lucas
# Processing Record 7 of Set 8 | babstovo
# Processing Record 8 of Set 8 | gornopravdinsk
# Processing Record 9 of Set 8 | lagoa
# Processing Record 10 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 8 | yorkton
# Processing Record 12 of Set 8 | havoysund
# Processing Record 13 of Set 8 | kaniama
# Processing Record 14 of Set 8 | grojec
# Processing Record 15 of Set 8 | igra
# Processing Record 16 of Set 8 | luderitz
# Processing Record 17 of Set 8 | pashiya
# Processing Record 18 of Set 8 | romny
# Processing Record 19 of Set 8 | lincoln
# Processing Record 20 of Set 8 | bambous virieux
# Processing Record 21 of Set 8 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 22 of Set 8 | masty
# Processing Record 23 of Set 8 | doctor juan manuel frutos
# Processing Record 24 of Set 8 | bay-khaak
# Processing Record 25 of Set 8 | caloundra
# Processing Record 26 of Set 8 | muriwai beach
# Processing Record 27 of Set 8 | gizo
# Processing Record 28 of Set 8 | shingu
# Processing Record 29 of Set 8 | iquitos
# Processing Record 30 of Set 8 | wewak
# Processing Record 31 of Set 8 | severo-kurilsk
# Processing Record 32 of Set 8 | sorland
# Processing Record 33 of Set 8 | kushiro
# Processing Record 34 of Set 8 | zaragoza
# Processing Record 35 of Set 8 | emerald
# Processing Record 36 of Set 8 | uvinza
# Processing Record 37 of Set 8 | vila
# Processing Record 38 of Set 8 | barcelona
# Processing Record 39 of Set 8 | portland
# Processing Record 40 of Set 8 | sterling
# Processing Record 41 of Set 8 | klyuchi
# Processing Record 42 of Set 8 | lhokseumawe
# Processing Record 43 of Set 8 | takoradi
# Processing Record 44 of Set 8 | lufilufi
# Processing Record 45 of Set 8 | itoman
# Processing Record 46 of Set 8 | kurchum
# Processing Record 47 of Set 8 | dwarka
# Processing Record 48 of Set 8 | tiznit
# Processing Record 49 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 8 | hami
# Processing Record 1 of Set 9 | homer
# Processing Record 2 of Set 9 | hambantota
# Processing Record 3 of Set 9 | freeport
# Processing Record 4 of Set 9 | cockburn town
# Processing Record 5 of Set 9 | flin flon
# Processing Record 6 of Set 9 | steyr
# Processing Record 7 of Set 9 | kruisfontein
# Processing Record 8 of Set 9 | san policarpo
# Processing Record 9 of Set 9 | mantua
# Processing Record 10 of Set 9 | oshkosh
# Processing Record 11 of Set 9 | narasannapeta
# Processing Record 12 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 9 | constitucion
# Processing Record 14 of Set 9 | san vicente
# Processing Record 15 of Set 9 | shreveport
# Processing Record 16 of Set 9 | teahupoo
# Processing Record 17 of Set 9 | sarankhola
# Processing Record 18 of Set 9 | mukhen
# Processing Record 19 of Set 9 | vao
# Processing Record 20 of Set 9 | sicamous
# Processing Record 21 of Set 9 | tottori
# Processing Record 22 of Set 9 | pyapon
# Processing Record 23 of Set 9 | katherine
# Processing Record 24 of Set 9 | roma
# Processing Record 25 of Set 9 | calella
# Processing Record 26 of Set 9 | benguela
# Processing Record 27 of Set 9 | vardo
# Processing Record 28 of Set 9 | novikovo
# Processing Record 29 of Set 9 | agadir
# Processing Record 30 of Set 9 | neijiang
# Processing Record 31 of Set 9 | chapais
# Processing Record 32 of Set 9 | sakakah
# Processing Record 33 of Set 9 | ascension
# Processing Record 34 of Set 9 | valparaiso
# Processing Record 35 of Set 9 | keuruu
# Processing Record 36 of Set 9 | touros
# Processing Record 37 of Set 9 | yeppoon
# Processing Record 38 of Set 9 | malibu
# Processing Record 39 of Set 9 | wichita
# Processing Record 40 of Set 9 | narsaq
# Processing Record 41 of Set 9 | benalla
# Processing Record 42 of Set 9 | stratford-upon-avon
# Processing Record 43 of Set 9 | aykhal
# Processing Record 44 of Set 9 | buchanan
# Processing Record 45 of Set 9 | brae
# Processing Record 46 of Set 9 | dalvik
# Processing Record 47 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 9 | xudat
# Processing Record 49 of Set 9 | hobyo
# Processing Record 50 of Set 9 | venice
# Processing Record 1 of Set 10 | souillac
# Processing Record 2 of Set 10 | norfolk
# Processing Record 3 of Set 10 | tambopata
# Processing Record 4 of Set 10 | pangody
# Processing Record 5 of Set 10 | caravelas
# Processing Record 6 of Set 10 | upington
# Processing Record 7 of Set 10 | yaan
# Processing Record 8 of Set 10 | wajir
# Processing Record 9 of Set 10 | dunedin
# Processing Record 10 of Set 10 | maloy
# Processing Record 11 of Set 10 | muros
# Processing Record 12 of Set 10 | mount gambier
# Processing Record 13 of Set 10 | bintulu
# Processing Record 14 of Set 10 | oum hadjer
# Processing Record 15 of Set 10 | rafaela
# Processing Record 16 of Set 10 | uttaradit
# Processing Record 17 of Set 10 | north vernon
# Processing Record 18 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 19 of Set 10 | tigil
# Processing Record 20 of Set 10 | port lincoln
# Processing Record 21 of Set 10 | kishi
# Processing Record 22 of Set 10 | creel
# Processing Record 23 of Set 10 | gushikawa
# Processing Record 24 of Set 10 | olafsvik
# Processing Record 25 of Set 10 | saint anthony
# Processing Record 26 of Set 10 | mogadouro
# Processing Record 27 of Set 10 | okhotsk
# Processing Record 28 of Set 10 | dos quebradas
# Processing Record 29 of Set 10 | changping
# Processing Record 30 of Set 10 | lensk
# Processing Record 31 of Set 10 | san quintin
# Processing Record 32 of Set 10 | bodden town
# Processing Record 33 of Set 10 | agadez
# Processing Record 34 of Set 10 | jardim
# Processing Record 35 of Set 10 | dom pedrito
# Processing Record 36 of Set 10 | qaqortoq
# Processing Record 37 of Set 10 | copala
# Processing Record 38 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 10 | luebo
# Processing Record 40 of Set 10 | ullapool
# Processing Record 41 of Set 10 | tazmalt
# Processing Record 42 of Set 10 | nanortalik
# Processing Record 43 of Set 10 | nantucket
# Processing Record 44 of Set 10 | ulverstone
# Processing Record 45 of Set 10 | ostrovnoy
# Processing Record 46 of Set 10 | tiksi
# Processing Record 47 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 10 | luwero
# Processing Record 49 of Set 10 | padang
# Processing Record 50 of Set 10 | tekeli
# Processing Record 1 of Set 11 | puri
# Processing Record 2 of Set 11 | calabozo
# Processing Record 3 of Set 11 | phonhong
# Processing Record 4 of Set 11 | egvekinot
# Processing Record 5 of Set 11 | havre-saint-pierre
# Processing Record 6 of Set 11 | cukai
# Processing Record 7 of Set 11 | pisco
# Processing Record 8 of Set 11 | langangen
# City not found. Skipping...
# Processing Record 9 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 10 of Set 11 | anadyr
# Processing Record 11 of Set 11 | mount isa
# Processing Record 12 of Set 11 | paramonga
# Processing Record 13 of Set 11 | faanui
# Processing Record 14 of Set 11 | bolgatanga
# Processing Record 15 of Set 11 | rapid valley
# Processing Record 16 of Set 11 | porosozero
# Processing Record 17 of Set 11 | itamaraca
# Processing Record 18 of Set 11 | bell ville
# Processing Record 19 of Set 11 | nyurba
# Processing Record 20 of Set 11 | sinnamary
# Processing Record 21 of Set 11 | puerto del rosario
# Processing Record 22 of Set 11 | linxia
# Processing Record 23 of Set 11 | zambezi
# Processing Record 24 of Set 11 | vega de alatorre
# Processing Record 25 of Set 11 | atambua
# Processing Record 26 of Set 11 | kaifeng
# Processing Record 27 of Set 11 | manakara
# Processing Record 28 of Set 11 | niquelandia
# Processing Record 29 of Set 11 | ahuimanu
# Processing Record 30 of Set 11 | jinji
# Processing Record 31 of Set 11 | cam ranh
# Processing Record 32 of Set 11 | kirovskiy
# Processing Record 33 of Set 11 | chifeng
# Processing Record 34 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 35 of Set 11 | newport
# Processing Record 36 of Set 11 | port hedland
# Processing Record 37 of Set 11 | barybino
# Processing Record 38 of Set 11 | yakeshi
# Processing Record 39 of Set 11 | mingyue
# Processing Record 40 of Set 11 | umba
# Processing Record 41 of Set 11 | sidi ali
# Processing Record 42 of Set 11 | san carlos de bariloche
# Processing Record 43 of Set 11 | yar-sale
# Processing Record 44 of Set 11 | launceston
# Processing Record 45 of Set 11 | barreirinha
# Processing Record 46 of Set 11 | atyrau
# Processing Record 47 of Set 11 | tsumeb
# Processing Record 48 of Set 11 | bryant
# Processing Record 49 of Set 11 | belaya gora
# Processing Record 50 of Set 11 | oranjemund
# Processing Record 1 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 12 | turukhansk
# Processing Record 3 of Set 12 | manzhouli
# Processing Record 4 of Set 12 | kuusamo
# Processing Record 5 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 6 of Set 12 | garissa
# Processing Record 7 of Set 12 | tutoia
# Processing Record 8 of Set 12 | salaspils
# Processing Record 9 of Set 12 | buenavista
# Processing Record 10 of Set 12 | nome
# Processing Record 11 of Set 12 | guerrero negro
# Processing Record 12 of Set 12 | morris
# Processing Record 13 of Set 12 | cap malheureux
# Processing Record 14 of Set 12 | tezu
# Processing Record 15 of Set 12 | bengkulu
# Processing Record 16 of Set 12 | rondonopolis
# Processing Record 17 of Set 12 | poum
# Processing Record 18 of Set 12 | altamont
# Processing Record 19 of Set 12 | talmenka
# Processing Record 20 of Set 12 | goya
# Processing Record 21 of Set 12 | porto uniao
# Processing Record 22 of Set 12 | kashi
# Processing Record 23 of Set 12 | ust-nera
# Processing Record 24 of Set 12 | ringsted
# Processing Record 25 of Set 12 | urdoma
# Processing Record 26 of Set 12 | denpasar
# Processing Record 27 of Set 12 | cabedelo
# Processing Record 28 of Set 12 | qasigiannguit
# Processing Record 29 of Set 12 | nola
# Processing Record 30 of Set 12 | maragogi
# Processing Record 31 of Set 12 | ca mau
# Processing Record 32 of Set 12 | abaete
# Processing Record 33 of Set 12 | college
# Processing Record 34 of Set 12 | zharkent
# Processing Record 35 of Set 12 | la paz
# Processing Record 36 of Set 12 | sistranda
# Processing Record 37 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 12 | noyabrsk
# Processing Record 39 of Set 12 | santa lucia
# Processing Record 40 of Set 12 | quelimane
# Processing Record 41 of Set 12 | santiago de puringla
# Processing Record 42 of Set 12 | koumac
# Processing Record 43 of Set 12 | banepa
# Processing Record 44 of Set 12 | mudgal
# Processing Record 45 of Set 12 | joshimath
# Processing Record 46 of Set 12 | bindi
# Processing Record 47 of Set 12 | lasa
# Processing Record 48 of Set 12 | peace river
# Processing Record 49 of Set 12 | bundaberg
# Processing Record 50 of Set 12 | alice springs
# Processing Record 1 of Set 13 | cikupa
# Processing Record 2 of Set 13 | nouadhibou
# Processing Record 3 of Set 13 | loandjili
# Processing Record 4 of Set 13 | lishui
# Processing Record 5 of Set 13 | eslamshahr
# Processing Record 6 of Set 13 | la peca
# Processing Record 7 of Set 13 | saurimo
# Processing Record 8 of Set 13 | charters towers
# Processing Record 9 of Set 13 | alashtar
# City not found. Skipping...
# Processing Record 10 of Set 13 | euclides da cunha
# Processing Record 11 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 12 of Set 13 | jammalamadugu
# Processing Record 13 of Set 13 | kasangulu
# Processing Record 14 of Set 13 | tahe
# Processing Record 15 of Set 13 | opuwo
# Processing Record 16 of Set 13 | portpatrick
# City not found. Skipping...
# Processing Record 17 of Set 13 | taga
# Processing Record 18 of Set 13 | ngunguru
# Processing Record 19 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 13 | auki
# Processing Record 21 of Set 13 | akdepe
# Processing Record 22 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 13 | talara
# Processing Record 25 of Set 13 | trorod
# Processing Record 26 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 13 | guane
# Processing Record 28 of Set 13 | marsa matruh
# Processing Record 29 of Set 13 | ugoofaaru
# Processing Record 30 of Set 13 | tecoanapa
# Processing Record 31 of Set 13 | tulum
# Processing Record 32 of Set 13 | bahia honda
# Processing Record 33 of Set 13 | maharajganj
# Processing Record 34 of Set 13 | mackay
# Processing Record 35 of Set 13 | nisko
# Processing Record 36 of Set 13 | erdenet
# Processing Record 37 of Set 13 | emba
# Processing Record 38 of Set 13 | nokaneng
# Processing Record 39 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 40 of Set 13 | lugovoy
# Processing Record 41 of Set 13 | conceicao do araguaia
# Processing Record 42 of Set 13 | sahuaripa
# Processing Record 43 of Set 13 | salt
# Processing Record 44 of Set 13 | saint-joseph
# Processing Record 45 of Set 13 | goroka
# Processing Record 46 of Set 13 | keokuk
# Processing Record 47 of Set 13 | lewisporte
# Processing Record 48 of Set 13 | uige
# Processing Record 49 of Set 13 | madang
# Processing Record 50 of Set 13 | deputatskiy
# Processing Record 1 of Set 14 | ixtapa
# Processing Record 2 of Set 14 | contai
# Processing Record 3 of Set 14 | dobryanka
# Processing Record 4 of Set 14 | kampong thum
# Processing Record 5 of Set 14 | los llanos de aridane
# Processing Record 6 of Set 14 | samarai
# Processing Record 7 of Set 14 | saryozek
# Processing Record 8 of Set 14 | lavumisa
# Processing Record 9 of Set 14 | nipawin
# Processing Record 10 of Set 14 | polson
# Processing Record 11 of Set 14 | haapsalu
# Processing Record 12 of Set 14 | wajima
# Processing Record 13 of Set 14 | kloulklubed
# Processing Record 14 of Set 14 | solnechnyy
# Processing Record 15 of Set 14 | neiafu
# Processing Record 16 of Set 14 | soyo
# Processing Record 17 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 14 | dicabisagan
# Processing Record 20 of Set 14 | makakilo city
# Processing Record 21 of Set 14 | mandiana
# Processing Record 22 of Set 14 | guantanamo
# Processing Record 23 of Set 14 | kupang
# Processing Record 24 of Set 14 | aksarka
# Processing Record 25 of Set 14 | kastamonu
# Processing Record 26 of Set 14 | general roca
# Processing Record 27 of Set 14 | alofi
# Processing Record 28 of Set 14 | waingapu
# Processing Record 29 of Set 14 | bondoukou
# Processing Record 30 of Set 14 | macusani
# Processing Record 31 of Set 14 | juegang
# Processing Record 32 of Set 14 | toppenish
# Processing Record 33 of Set 14 | placido de castro
# Processing Record 34 of Set 14 | mount pleasant
# Processing Record 35 of Set 14 | sisimiut
# Processing Record 36 of Set 14 | kirakira
# Processing Record 37 of Set 14 | yulara
# Processing Record 38 of Set 14 | mana
# Processing Record 39 of Set 14 | le port
# Processing Record 40 of Set 14 | sabang
# Processing Record 41 of Set 14 | qui nhon
# Processing Record 42 of Set 14 | lake mary
# Processing Record 43 of Set 14 | sassandra
# Processing Record 44 of Set 14 | kudat
# Processing Record 45 of Set 14 | kumano
# Processing Record 46 of Set 14 | hopkinton
# Processing Record 47 of Set 14 | stokmarknes
# Processing Record 48 of Set 14 | sao joao da barra
# Processing Record 49 of Set 14 | penzance
# Processing Record 50 of Set 14 | larsnes
# Processing Record 1 of Set 15 | miracema
# Processing Record 2 of Set 15 | palatka
# Processing Record 3 of Set 15 | sept-iles
# Processing Record 4 of Set 15 | ucluelet
# Processing Record 5 of Set 15 | luba
# Processing Record 6 of Set 15 | shetpe
# Processing Record 7 of Set 15 | caiaponia
# Processing Record 8 of Set 15 | vicuna
# Processing Record 9 of Set 15 | inhambane
# Processing Record 10 of Set 15 | ous
# Processing Record 11 of Set 15 | that phanom
# Processing Record 12 of Set 15 | villamontes
# Processing Record 13 of Set 15 | chilmari
# Processing Record 14 of Set 15 | villanueva
# Processing Record 15 of Set 15 | sawtell
# Processing Record 16 of Set 15 | znamenskoye
# Processing Record 17 of Set 15 | araouane
# Processing Record 18 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 15 | quatre cocos
# Processing Record 20 of Set 15 | lashio
# Processing Record 21 of Set 15 | capiibary
# Processing Record 22 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 15 | raga
# Processing Record 24 of Set 15 | tateyama
# Processing Record 25 of Set 15 | sarh
# Processing Record 26 of Set 15 | polis
# Processing Record 27 of Set 15 | aripuana
# Processing Record 28 of Set 15 | mayumba
# Processing Record 29 of Set 15 | maraa
# Processing Record 30 of Set 15 | rodos
# Processing Record 31 of Set 15 | filingue
# Processing Record 32 of Set 15 | iqaluit
# Processing Record 33 of Set 15 | kununurra
# Processing Record 34 of Set 15 | nador
# Processing Record 35 of Set 15 | port hawkesbury
# Processing Record 36 of Set 15 | skjervoy
# Processing Record 37 of Set 15 | monte azul
# Processing Record 38 of Set 15 | conde
# Processing Record 39 of Set 15 | fereydun kenar
# Processing Record 40 of Set 15 | trinidad
# Processing Record 41 of Set 15 | yenotayevka
# Processing Record 42 of Set 15 | kuryk
# Processing Record 43 of Set 15 | medeiros neto
# Processing Record 44 of Set 15 | gashua
# Processing Record 45 of Set 15 | utmanzai
# Processing Record 46 of Set 15 | acarau
# Processing Record 47 of Set 15 | nagato
# Processing Record 48 of Set 15 | baykit
# Processing Record 49 of Set 15 | coahuayana
# Processing Record 50 of Set 15 | jumla
# Processing Record 1 of Set 16 | meulaboh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Saskylakh      RU  71.9167  114.0833     45.61        75         100
# 1         Lieksa      FI  63.3167   30.0167     57.78        85          26
# 2          Vaini      TO -21.2000 -175.2000     78.96        94          75
# 3       Hermanus      ZA -34.4187   19.2345     38.80        75           0
# 4         Tromso      NO  69.6496   18.9570     57.38        82           0
# 5      Boa Vista      BR   2.8197  -60.6733     80.58        78          40
# 6         Kodiak      US  57.7900 -152.4072     63.91        72          75
# 7      Dhidhdhoo      MV   6.8833   73.1000     78.57        77         100
# 8           Lata      PT  40.1629   -8.3327     68.50        58           0
# 9  Mar Del Plata      AR -38.0023  -57.5575     52.88        88          65
#
#    Wind Speed   Current Description                 Date
# 0        9.60       overcast clouds  2022-08-01 04:11:24
# 1        4.68      scattered clouds  2022-08-01 04:11:25
# 2        6.91         broken clouds  2022-08-01 04:11:26
# 3        7.72             clear sky  2022-08-01 04:11:27
# 4        0.00             clear sky  2022-08-01 04:11:28
# 5        2.30      scattered clouds  2022-08-01 04:11:29
# 6        0.00         broken clouds  2022-08-01 04:11:29
# 7       31.90  heavy intensity rain  2022-08-01 04:11:30
# 8        2.35             clear sky  2022-08-01 04:11:31
# 9        4.00                  mist  2022-08-01 04:11:31

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
